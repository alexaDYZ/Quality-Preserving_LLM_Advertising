# %% [markdown]
# # Heterogeneous QP Single: Data Generation
#
# This notebook runs the standalone synthetic data generator for the consumer-heterogeneity extension. It does not modify Dai/Han's original notebooks or logs.

# %%
from pathlib import Path
from generate_data import build_dataset

output_dir = Path('generated_data')
summary = build_dataset(output_dir=output_dir, n_users=100, seed=211)
summary
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# {'segment_counts': {'luxury': 50, 'budget': 50},
#  'generation_archetype_counts': {'luxury': 50, 'budget': 50},
#  'duplicate_memory_count': 0,
#  'target_mean_s_iu': {'budget__both': 0.674176,
#   'budget__budget': 0.867289,
#   'budget__luxury': 0.205724,
#   'budget__neither': 0.109802,
#   'luxury__both': 0.699014,
#   'luxury__budget': 0.189574,
#   'luxury__luxury': 0.893699,
#   'luxury__neither': 0.115291},
#  'within_segment_user_mean_s_iu_std': {'budget': 0.020861, 'luxury': 0.019749},
#  'checks': {'has_100_users': True,
#   'memories_not_duplicates': True,
#   'has_budget_and_luxury_segments': True,
#   'budget_scores_budget_ads_higher_than_luxury_ads': True,
#   'luxury_scores_luxury_ads_higher_than_budget_ads': True,
#   'irrelevant_ads_low_on_average': True,
#   'budget_users_have_score_variation': True,
#   'luxury_users_have_score_variation': True},
#  'embedding_backend': 'sentence_transformers',
# ...
